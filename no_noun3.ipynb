# %%
import pandas as pd
import numpy as np
# train data를 df로
df_train = pd.read_excel(r'.\projects\wannaone\remixed.xlsx')
# data.frame을 NumPy 배열로
# train set
text_train = df_train['contents'].as_matrix()
y_train = df_train['label'].as_matrix()

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression as lgt
from hanspell import spell_checker

# tokeinize - Kkma
from konlpy.tag import Komoran
komoran = Komoran()
words = ['NNG','VV','VA','VX','VCP','VCN','MAG','MAJ','IC','SE','SF','XR']
def tokenize(doc):
    tagged = ['/'.join(t) for t in komoran.pos(doc)]
    result = [word for word in tagged if word.split('/')[-1] in words]
    return result
tfidf = TfidfVectorizer(tokenizer=tokenize,ngram_range=(1,3),min_df=3)

# %%
input_data = tfidf.fit_transform(text_train.astype('U'))
clf_1 = lgt(C=10)
print('ML Start')
model = clf_1.fit(input_data,y_train)
print('ML Finish')
# Out:
# ML Start
# ML Finish

# %%
model.score(input_data,y_train)
# Out:
# 0.94064382038177075

# %%
# read_data
df_1 = pd.read_csv(r'.\projects\wannaone\crawled_data18.txt',
                   delimiter='\t',keep_default_na=False,header=None)

# %%
h_x = df_1[3].as_matrix()

# %%
#wanna_one
input_test = tfidf.transform(h_x)
result = model.predict(input_test)
result_p = model.predict_proba(input_test)

# %%
df_prob = pd.DataFrame(result_p)
result_p0 = df_prob[0]
result_p1 = df_prob[1]
point = round((result_p1 - result_p0),2)*100

data = {'contents':h_x,
       'predict_label':result,
       'point':point,
       'neg':result_p0,
       'pos':result_p1}
data_pandas = pd.DataFrame(data)
from IPython.display import display
display(data_pandas)
# Out:
#                                                contents       neg  point  \
# 0     오늘 친구가 워너원 봤대요ㅠ ㅠ ㅠ ㅠ엉엉 같이 함께 뭐 먹었나봐여ㅠㅠㅠㅠㅠㅠㅠㅠㅠ...  0.230240   54.0
# 1     올해 가장 행복한 순간 TOP 3를 꼽자면 널 처음 알게된 순간, 널 처음 본 순간...  0.032464   94.0
# 2                          워너원 망했다고 광광댔던 사람들 우는 소리 들린다   0.588590  -18.0
# 3     [단독] '프듀2' 워너원 11人, 합숙 시작 ＂첫 스케줄은 화보 촬영＂ (출처 :...  0.035326   93.0
# 4     우리 배챙이 진영이의 워너원 데뷔를 축하하며 소소한 이벤트를 진행합니다. 계정팔로+...  0.092528   81.0
# 5                    170616 대휘 안우러 #이대휘 #대휘 #강다니엘 #워너원   0.041193   92.0
# 6      워너원 트위터 헤더 ・:*:・゜  저장하실 때는 리트윗 해 주세요   재가공 재배...  0.265299   47.0
# 7     [단독] '프듀2' 워너원 11人, 합숙 시작 ＂첫 스케줄은 화보 촬영＂ (출처 :...  0.035326   93.0
# 8                             워너원 화보 촬영  성운이 화보.......   0.209584   58.0
# 9              '프듀2' 데뷔팀 워너원, 자연주의 화장품 CF 모델 발탁 '대세 예약'  0.093217   81.0
# 10    이니스프리는 화산송이 컬러 클레이 마스크를 사용한 워너원 멤버들의 각기 다른 컬러마...  0.179209   64.0
# 11                          워너원 잘됐음 조켓는데 동반자네 소속사야..  .  0.422538   15.0
# 12                          하앙 저도 워너원은 황제+미자단만 기머합니다~^^  0.260191   48.0
# 13    워너원이고 자시고......., 큡즈 브랜뉴즈에 집중할래... 지후니랑 지녕이도 가...  0.172352   66.0
# 14                    워너원의 일부 멤버들이 숙소에 들어갔다고 와엠씨가 말했슴다   0.626392  -25.0
# 15              헐 대박 내일 워너원 첫 스케줄 ㅠㅠㅠ 민현아 잘해서 꼭 성곡하자 !   0.108425   78.0
# 16                         ..프로듀스 콘서트... 워너원콘서트 가고싶다...  0.346426   31.0
# 17                         워너원 망했다고 광광댔던 사람들 우는 소리 들린다   0.588590  -18.0
# 18                       핡 맞팔감사합니다♡ 워너원 앞길에 화창한 봄날만있기를@  0.492662    1.0
# 19    [단독] '프듀2' 워너원 11人, 합숙 시작 ＂첫 스케줄은 화보 촬영＂ (출처 :...  0.035326   93.0
# 20    m2 워너원 데뷔하는 애들 개개인 영상보는데 다른 애들이 축하하고 기뻐하고 또 아쉬...  0.030454   94.0
# 21    이니스프리, '프듀 101'워너원 모델 발탁 (출처 : 이데일리 | 네이버 뉴스) ...  0.034989   93.0
# 22    [단독] '프듀2' 워너원 11人, 합숙 시작 ＂첫 스케줄은 화보 촬영＂ (출처 :...  0.035326   93.0
# 23                       주간아이돌도 찍어주세요.... 워너원 브이앱주세요...  0.609926  -22.0
# 24                           집 가면 방탄이랑.. 워너원 트친소 시트 써야지  0.232657   53.0
# 25    #PRODUCE101 #프로듀스101시즌2 #워너원 #라이관린 아버지와 누나가 와서...  0.114914   77.0
# 26                  뿌엥엥 •°(´^｀)°• 사랑해 아가야 #워너원 #막내 #이대휘  0.012868   97.0
# 27                   형식이는 휴식기니까 다시 활동하면 워너원이랑 같이 덕질해야지~  0.063916   87.0
# 28    MAIN 워너원 데뷔 멤버 11명과 연습생들을 응원합니다 대휘를 아주 조금! 더 좋...  0.013311   97.0
# 29    물만두 이쁘다고 동네방네 자랑하고싶다 #김재환 #김재환데뷔축하해 #워너원 #우리원 ...  0.156149   69.0
# ...                                                 ...       ...    ...
# 8041  ฉันชอบวิดีโอ @YouTube http://youtu.be/I966WEXX...  0.582170  -16.0
# 8042        본계선 워너원 얘기 자주 해지말어야지,,, 워너원계 오실분은 언제나 뎸주시기ㅣ  0.133878   73.0
# 8043  내가 워너원 좋아하면서까지 배척으로 고통당해야 한다니 너무 끔찍한 한국 가요계 문화...  0.976203  -95.0
# 8044                             민현이가 워너원 숙소 들어갔어요 ...?  0.460793    8.0
# 8045  안녕하세요. 위너원이 아니라 워너원(Wanna one)입니다. 위너 검색하다가 플필...  0.134518   73.0
# 8046  @wanna_one45 트친소 흔적 남겨주셔서 찾아왔어요 !! 팔로누르고 갈게요 !...  0.006645   99.0
# 8047  #강다니엘 #워너원 #wanna_one 워너원 11명 다 예뻐합니다내새끼 패거나 지...  0.809115  -62.0
# 8048                 [워너원 X M2] B-day WANNA ONE l 라이관린   0.087811   82.0
# 8049  앗싴ㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# 8070                      씨나인선생님들 진영이 워너원 끝나도 잘 데뷔시켜주세요  0.443407   11.0
#
#            pos  predict_label
# 0     0.769760              1
# 1     0.967536              1
# 2     0.411410              0
# 3     0.964674              1
# 4     0.907472              1
# 5     0.958807              1
# 6     0.734701              1
# 7     0.964674              1
# 8     0.790416              1
# 9     0.906783              1
# 10    0.820791              1
# 11    0.577462              1
# 12    0.739809              1
# 13    0.827648              1
# 14    0.373608              0
# 15    0.891575              1
# 16    0.653574              1
# 17    0.411410              0
# 18    0.507338              1
# 19    0.964674              1
# 20    0.969546              1
# 21    0.965011              1
# 22    0.964674              1
# 23    0.390074              0
# 24    0.767343              1
# 25    0.885086              1
# 26    0.987132              1
# 27    0.936084              1
# 28    0.986689              1
# 29    0.843851              1
# ...        ...            ...
# 8041  0.417830              0
# 8042  0.866122              1
# 8043  0.023797              0
# 8044  0.539207              1
# 8045  0.865482              1
# 8046  0.993355              1
# 8047  0.190885              0
# 8048  0.912189              1
# 8049  0.986011              1
# 8050  0.883905              1
# 8051  0.689586              1
# 8052  0.939094              1
# 8053  0.879670              1
# 8054  0.420366              0
# 8055  0.995018              1
# 8056  0.030952              0
# 8057  0.937113              1
# 8058  0.997003              1
# 8059  0.395477              0
# 8060  0.987067              1
# 8061  0.912189              1
# 8062  0.007405              0
# 8063  0.804143              1
# 8064  0.778618              1
# 8065  0.791517              1
# 8066  0.940580              1
# 8067  0.524795              1
# 8068  0.973125              1
# 8069  0.973094              1
# 8070  0.556593              1
#
# [8071 rows x 5 columns]

# %%
data_pandas.to_excel("result_k3.xlsx",encoding='utf-8')

# %%
tokenize('파이팅!!')
# Out:
# []

# %%
komoran.pos('대박 워너원 이니스프리 cf찍는데 ㅋㅋㅋㅋㅋㅋㅋㅋㅋ지훈이는 홍조 머그런걸로하겠지 으앙 기대돼 ')
# Out:
# [('대', 'XPN'),
#  ('박', 'NNP'),
#  ('워너', 'NNP'),
#  ('원', 'NNB'),
#  ('이니스프리', 'NNP'),
#  ('cf', 'SL'),
#  ('찍', 'VV'),
#  ('는데', 'EC'),
#  ('ㅋㅋㅋㅋㅋㅋㅋㅋㅋ지훈이는', 'NA'),
#  ('홍', 'NNP'),
#  ('조', 'NNB'),
#  ('머', 'NP'),
#  ('그렇', 'VA'),
#  ('ㄴ', 'ETM'),
#  ('것', 'NNB'),
#  ('로', 'JKB'),
#  ('하', 'VV'),
#  ('겠', 'EP'),
#  ('지', 'EC'),
#  ('으앙', 'IC'),
#  ('기대', 'NNG'),
#  ('되', 'XSV'),
#  ('어', 'EC')]

# %%
tokenize('파이팅!!')
# Out:
# ['!/SF']

# %%
tokenize('핡 맞팔감사합니다♡ 워너원 앞길에 화창한 봄날만있기를@')
# Out:
# ['맞/VV', '팔/VV', '앞길/NNG', '화창/XR']
